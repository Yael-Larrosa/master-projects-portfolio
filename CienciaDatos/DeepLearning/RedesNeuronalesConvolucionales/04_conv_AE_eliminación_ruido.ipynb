# %% [markdown]
# # **Autoencoders para eliminar ruido**

# %% [markdown]
# Ahora, para entrenar el autoencoder:
# - Entrada al modelo: patrones con ruido
# - Salida deseada: patrones sin ruido.

# %%
COLAB = True

# %%
import numpy as np
import matplotlib.pyplot as plt
import keras
from keras import layers
from keras.datasets import mnist

from IPython.display import SVG
from keras.utils import model_to_dot

# %%
def plot_image(image, cmap="binary"):
    plt.imshow(image, cmap=cmap)
    plt.axis("off")

def show_model(model):
    if not COLAB:
        display(SVG(model_to_dot(model,show_shapes=True).create(prog='dot', format='svg')))
    else:
        display(SVG(model_to_dot(model, show_shapes=True, dpi=72).create(prog='dot', format='svg')))

# %%
(X_trval, y_trval), (X_test, y_test) = mnist.load_data()

X_train, X_valid = X_trval[:-5000], X_trval[-5000:]
y_train, y_valid = y_trval[:-5000], y_trval[-5000:]
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
def show_ests(y, title=None):
    clases, counts = np.unique(y, return_counts=True)
    plt.figure(figsize=(7,1.5))
    plt.bar(clases, counts)
    if title:
        plt.title(title, fontsize=18)
    plt.xticks(clases)
    plt.show()

show_ests(y_train, title="Training")
show_ests(y_valid, title="Validación")
show_ests(y_valid, title="Test")

# %%
X_train = X_train.astype('float32') / 255
X_valid = X_valid.astype('float32') / 255
X_test = X_test.astype('float32') / 255
print(X_train.shape)
print(X_test.shape)
# Out:
# (55000, 28, 28)
# (10000, 28, 28)

# %%
nrows=10
ncols=10

inds = np.random.randint(0, len(X_train), nrows*ncols)

plt.figure(figsize=(10,10/ncols*nrows))
for i,ind in enumerate(inds):
    plt.subplot(nrows, ncols, i+1)
    plot_image(X_train[ind], cmap="Greys")

# %%
noise_factor = 0.5
X_train_noisy = X_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=X_train.shape)
X_valid_noisy = X_valid + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=X_valid.shape)
X_test_noisy  = X_test  + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=X_test.shape)

X_train_noisy = np.clip(X_train_noisy, 0., 1.)
X_valid_noisy = np.clip(X_valid_noisy, 0., 1.)
X_test_noisy  = np.clip(X_test_noisy, 0., 1.)

# %%
plt.figure(figsize=(10,10/ncols*nrows))
for i,ind in enumerate(inds):
    plt.subplot(nrows, ncols, i+1)
    plot_image(X_train_noisy[ind], cmap="Greys")

# %% [markdown]
# If you squint you can still recognize them, but barely. Can our autoencoder learn to recover the original digits? Let's find out.
#
# Compared to the previous convolutional autoencoder, in order to improve the quality of the reconstructed, we'll use a slightly different model with more filters per layer:

# %%
# This is our input image
input_img = keras.Input(shape=(28,28,))

# "encoded" is the encoded representation of the input
encoded = layers.Reshape((28,28,1))(input_img)
encoded = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(encoded)
encoded = layers.MaxPooling2D((2, 2), padding='same')(encoded)
encoded = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(encoded)
encoded = layers.MaxPooling2D((2, 2), padding='same')(encoded)

# at this point the representation is (7, 7, 32)

# "decoded" is the lossy reconstruction of the input
decoded = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(encoded)
decoded = layers.UpSampling2D((2, 2))(decoded)
decoded = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(decoded)
decoded = layers.UpSampling2D((2, 2))(decoded)
decoded = layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(decoded)
decoded = layers.Reshape([28,28])(decoded)

# %%
# This model maps an input to its encoded representation
encoder = keras.Model(input_img, encoded)

# Create the decoder model
decoder = keras.Model(encoded, decoded)

# This model maps an input to its reconstruction
autoencoder = keras.Model(input_img, decoded)

# %%
encoder.summary()
show_model(encoder)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28)]          0
#
#  reshape (Reshape)           (None, 28, 28, 1)         0
#
#  conv2d (Conv2D)             (None, 28, 28, 32)        320
#
#  max_pooling2d (MaxPooling2  (None, 14, 14, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 32)        9248
#
#  max_pooling2d_1 (MaxPoolin  (None, 7, 7, 32)          0
#  g2D)
#
# =================================================================
# Total params: 9568 (37.38 KB)
# Trainable params: 9568 (37.38 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
decoder.summary()

show_model(decoder)
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 7, 7, 32)]        0
#
#  conv2d_2 (Conv2D)           (None, 7, 7, 32)          9248
#
#  up_sampling2d (UpSampling2  (None, 14, 14, 32)        0
#  D)
#
#  conv2d_3 (Conv2D)           (None, 14, 14, 32)        9248
#
#  up_sampling2d_1 (UpSamplin  (None, 28, 28, 32)        0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 28, 28, 1)         289
#
#  reshape_1 (Reshape)         (None, 28, 28)            0
#
# =================================================================
# Total params: 18785 (73.38 KB)
# Trainable params: 18785 (73.38 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
autoencoder.summary()

show_model(autoencoder)
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28)]          0
#
#  reshape (Reshape)           (None, 28, 28, 1)         0
#
#  conv2d (Conv2D)             (None, 28, 28, 32)        320
#
#  max_pooling2d (MaxPooling2  (None, 14, 14, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 32)        9248
#
#  max_pooling2d_1 (MaxPoolin  (None, 7, 7, 32)          0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 7, 7, 32)          9248
#
#  up_sampling2d (UpSampling2  (None, 14, 14, 32)        0
#  D)
#
#  conv2d_3 (Conv2D)           (None, 14, 14, 32)        9248
#
#  up_sampling2d_1 (UpSamplin  (None, 28, 28, 32)        0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 28, 28, 1)         289
#
#  reshape_1 (Reshape)         (None, 28, 28)            0
#
# =================================================================
# Total params: 28353 (110.75 KB)
# Trainable params: 28353 (110.75 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# configure the model to use a per-pixel binary crossentropy loss
# and the Adam optimizer:

autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %%
autoencoder.fit(X_train_noisy, X_train,
                epochs=100,
                batch_size=128,
                shuffle=True,
                validation_data=(X_valid_noisy, X_valid))
# Out:
# Epoch 1/100
# 430/430 [==============================] - 11s 8ms/step - loss: 0.1621 - val_loss: 0.1193
# Epoch 2/100
# 430/430 [==============================] - 3s 7ms/step - loss: 0.1143 - val_loss: 0.1123
# Epoch 3/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.1087 - val_loss: 0.1078
# Epoch 4/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.1059 - val_loss: 0.1055
# Epoch 5/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.1040 - val_loss: 0.1047
# Epoch 6/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.1027 - val_loss: 0.1032
# Epoch 7/100
# 430/430 [==============================] - 3s 7ms/step - loss: 0.1016 - val_loss: 0.1021
# Epoch 8/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.1006 - val_loss: 0.1010
# Epoch 9/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0998 - val_loss: 0.1007
# Epoch 10/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0991 - val_loss: 0.0997
# Epoch 11/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0986 - val_loss: 0.0991
# Epoch 12/100
# 430/430 [==============================] - 3s 7ms/step - loss: 0.0981 - val_loss: 0.0988
# Epoch 13/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0976 - val_loss: 0.0984
# Epoch 14/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0973 - val_loss: 0.0980
# Epoch 15/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0970 - val_loss: 0.0985
# Epoch 16/100
# 430/430 [==============================] - 3s 7ms/step - loss: 0.0966 - val_loss: 0.0976
# Epoch 17/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0964 - val_loss: 0.0972
# Epoch 18/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0962 - val_loss: 0.0969
# Epoch 19/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0959 - val_loss: 0.0969
# Epoch 20/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0957 - val_loss: 0.0967
# Epoch 21/100
# 430/430 [==============================] - 3s 7ms/step - loss: 0.0956 - val_loss: 0.0968
# Epoch 22/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0954 - val_loss: 0.0964
# Epoch 23/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0953 - val_loss: 0.0965
# Epoch 24/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0951 - val_loss: 0.0962
# Epoch 25/100
# 430/430 [==============================] - 3s 7ms/step - loss: 0.0951 - val_loss: 0.0963
# Epoch 26/100
# 430/430 [==============================] - 3s 7ms/step - loss: 0.0950 - val_loss: 0.0960
# Epoch 27/100
# 430/430 [==============================] - 4s 8ms/step - loss: 0.0948 - val_loss: 0.0960
# Epoch 28/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0948 - val_loss: 0.0961
# Epoch 29/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0947 - val_loss: 0.0958
# Epoch 30/100
# 430/430 [==============================] - 3s 7ms/step - loss: 0.0947 - val_loss: 0.0958
# Epoch 31/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0945 - val_loss: 0.0957
# Epoch 32/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0945 - val_loss: 0.0956
# Epoch 33/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0944 - val_loss: 0.0958
# Epoch 34/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0944 - val_loss: 0.0956
# Epoch 35/100
# 430/430 [==============================] - 3s 7ms/step - loss: 0.0943 - val_loss: 0.0958
# Epoch 36/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0943 - val_loss: 0.0958
# Epoch 37/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0942 - val_loss: 0.0953
# Epoch 38/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0941 - val_loss: 0.0954
# Epoch 39/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0941 - val_loss: 0.0955
# Epoch 40/100
# 430/430 [==============================] - 3s 7ms/step - loss: 0.0940 - val_loss: 0.0955
# Epoch 41/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0940 - val_loss: 0.0953
# Epoch 42/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0940 - val_loss: 0.0951
# Epoch 43/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0939 - val_loss: 0.0952
# Epoch 44/100
# 430/430 [==============================] - 3s 7ms/step - loss: 0.0939 - val_loss: 0.0956
# Epoch 45/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0939 - val_loss: 0.0955
# Epoch 46/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0938 - val_loss: 0.0951
# Epoch 47/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0938 - val_loss: 0.0952
# Epoch 48/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0938 - val_loss: 0.0954
# Epoch 49/100
# 430/430 [==============================] - 3s 7ms/step - loss: 0.0937 - val_loss: 0.0952
# Epoch 50/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0937 - val_loss: 0.0953
# Epoch 51/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0937 - val_loss: 0.0950
# Epoch 52/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0936 - val_loss: 0.0951
# Epoch 53/100
# 430/430 [==============================] - 3s 7ms/step - loss: 0.0936 - val_loss: 0.0950
# Epoch 54/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0936 - val_loss: 0.0952
# Epoch 55/100
# 430/430 [==============================] - 3s 7ms/step - loss: 0.0936 - val_loss: 0.0950
# Epoch 56/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0935 - val_loss: 0.0950
# Epoch 57/100
# 430/430 [==============================] - 3s 7ms/step - loss: 0.0935 - val_loss: 0.0949
# Epoch 58/100
# 430/430 [==============================] - 3s 7ms/step - loss: 0.0935 - val_loss: 0.0949
# Epoch 59/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0935 - val_loss: 0.0951
# Epoch 60/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0935 - val_loss: 0.0951
# Epoch 61/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0934 - val_loss: 0.0949
# Epoch 62/100
# 430/430 [==============================] - 3s 7ms/step - loss: 0.0934 - val_loss: 0.0949
# Epoch 63/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0934 - val_loss: 0.0950
# Epoch 64/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0934 - val_loss: 0.0954
# Epoch 65/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0934 - val_loss: 0.0950
# Epoch 66/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0934 - val_loss: 0.0948
# Epoch 67/100
# 430/430 [==============================] - 3s 7ms/step - loss: 0.0933 - val_loss: 0.0950
# Epoch 68/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0933 - val_loss: 0.0949
# Epoch 69/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0933 - val_loss: 0.0948
# Epoch 70/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0933 - val_loss: 0.0948
# Epoch 71/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0933 - val_loss: 0.0949
# Epoch 72/100
# 430/430 [==============================] - 3s 7ms/step - loss: 0.0933 - val_loss: 0.0950
# Epoch 73/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0933 - val_loss: 0.0952
# Epoch 74/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0933 - val_loss: 0.0949
# Epoch 75/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0932 - val_loss: 0.0948
# Epoch 76/100
# 430/430 [==============================] - 3s 7ms/step - loss: 0.0932 - val_loss: 0.0948
# Epoch 77/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0933 - val_loss: 0.0950
# Epoch 78/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0932 - val_loss: 0.0947
# Epoch 79/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0932 - val_loss: 0.0948
# Epoch 80/100
# 430/430 [==============================] - 3s 7ms/step - loss: 0.0932 - val_loss: 0.0950
# Epoch 81/100
# 430/430 [==============================] - 3s 7ms/step - loss: 0.0932 - val_loss: 0.0948
# Epoch 82/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0931 - val_loss: 0.0948
# Epoch 83/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0932 - val_loss: 0.0949
# Epoch 84/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0931 - val_loss: 0.0949
# Epoch 85/100
# 430/430 [==============================] - 3s 7ms/step - loss: 0.0931 - val_loss: 0.0947
# Epoch 86/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0931 - val_loss: 0.0949
# Epoch 87/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0931 - val_loss: 0.0947
# Epoch 88/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0931 - val_loss: 0.0949
# Epoch 89/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0931 - val_loss: 0.0951
# Epoch 90/100
# 430/430 [==============================] - 3s 7ms/step - loss: 0.0931 - val_loss: 0.0947
# Epoch 91/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0930 - val_loss: 0.0946
# Epoch 92/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0931 - val_loss: 0.0946
# Epoch 93/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0930 - val_loss: 0.0946
# Epoch 94/100
# 430/430 [==============================] - 3s 7ms/step - loss: 0.0930 - val_loss: 0.0947
# Epoch 95/100
# 430/430 [==============================] - 3s 7ms/step - loss: 0.0930 - val_loss: 0.0946
# Epoch 96/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0930 - val_loss: 0.0946
# Epoch 97/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0930 - val_loss: 0.0946
# Epoch 98/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0930 - val_loss: 0.0946
# Epoch 99/100
# 430/430 [==============================] - 3s 7ms/step - loss: 0.0930 - val_loss: 0.0948
# Epoch 100/100
# 430/430 [==============================] - 3s 6ms/step - loss: 0.0929 - val_loss: 0.0946

# %%
# Encode and decode some digits
# Note that we take them from the *test* set
encoded_imgs = encoder.predict(X_test_noisy)
decoded_imgs = decoder.predict(encoded_imgs)
# Out:
# 313/313 [==============================] - 1s 2ms/step
# 313/313 [==============================] - 1s 2ms/step

# %%
encoded_imgs.shape
# Out:
# (10000, 7, 7, 32)

# %%
n = 10  # How many digits we will display
plt.figure(figsize=(20, 4))
for i in range(n):
    # Display original
    ax = plt.subplot(2, n, i + 1)
    plot_image(X_test_noisy[i], cmap="Greys")
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plot_image(decoded_imgs[i], cmap="Greys")
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# It seems to work pretty well. If you scale this process to a bigger convnet, you can start building document denoising or audio denoising models. Kaggle has an interesting dataset about this: https://www.kaggle.com/c/denoising-dirty-documents

# %% [markdown]
# **Imágenes sin ruido**

# %%
n = 10

encoded_imgs = encoder.predict(X_test[:n])
encoded_imgs.min(), encoded_imgs.max(), encoded_imgs.mean(), encoded_imgs.std()
# Out:
# 1/1 [==============================] - 0s 102ms/step
# (0.0, 1.5637846, 0.09253666, 0.18707034)

# %%
encoded_imgs.shape
# Out:
# (10, 7, 7, 32)

# %% [markdown]
# **Imágenes con ruido**

# %%
encoded_noisy_imgs = encoder.predict(X_test_noisy[:n])
encoded_noisy_imgs.min(), encoded_noisy_imgs.max(), encoded_noisy_imgs.mean(), encoded_noisy_imgs.std()
# Out:
# 1/1 [==============================] - 0s 20ms/step
# (0.0, 1.3045282, 0.10649329, 0.18006289)

# %%
encoded_noisy_imgs.shape
# Out:
# (10, 7, 7, 32)

# %% [markdown]
# ## Detección de anomalías en test

# %%
differences = np.array(X_test - autoencoder(X_test))

differences.shape
# Out:
# (10000, 28, 28)

# %%
differences_flat = differences.reshape(len(differences), -1)

differences_flat.shape
# Out:
# (10000, 784)

# %%
errors = (np.array(differences_flat)**2).mean(axis=1)

errors.shape
# Out:
# (10000,)

# %%
inds_maximos = np.argsort(errors)[::-1]

# %%
plt.hist(errors, bins=20);

# %%
def show_error(error):
    img = np.zeros((error.shape[0],error.shape[1],3))
    img[:,:,1] = np.clip(error, 0, 1)
    img[:,:,2] = np.clip(error, 0, 1)

    img[:,:,0] = -np.clip(error, -1, 0)
    img[:,:,1] = img[:,:,1] - np.clip(error, -1, 0)

    plt.imshow(1-img, vmin=0, vmax=1)
    plt.axis("off")

# %%
ncols=15
nrows=2

aux = 1
for i,ind in enumerate(inds_maximos[:(nrows*ncols)]):
    if aux == 1:
        plt.figure(figsize=(15,15/ncols*nrows))
    plt.subplot(2, ncols, aux)
    plot_image(X_test[ind], cmap="Greys")
    plt.subplot(2, ncols, ncols + aux)
    show_error(differences[ind])
    if aux == ncols:
        plt.show()
        aux = 1
    else:
        aux = aux + 1
